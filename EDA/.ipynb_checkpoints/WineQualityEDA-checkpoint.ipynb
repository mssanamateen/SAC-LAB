# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("winequality-red.csv",sep=";")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# | Column Name | Description | Data Type | Role |
# |--------------|--------------|-----------|------|
# | **fixed acidity** | Non-volatile acids (e.g., tartaric acid) that do not evaporate easily. Affects wine’s taste and stability. | float | Feature |
# | **volatile acidity** | Amount of acetic acid in the wine (gives vinegar taste if high). | float | Feature |
# | **citric acid** | Adds freshness and flavor; affects acidity balance. | float | Feature |
# | **residual sugar** | Remaining sugar after fermentation; indicates sweetness. | float | Feature |
# | **chlorides** | Salt content in the wine. Too much can spoil the taste. | float | Feature |
# | **free sulfur dioxide** | Free SO₂ prevents microbial growth and oxidation. | float | Feature |
# | **total sulfur dioxide** | Sum of free and bound SO₂. High levels affect aroma. | float | Feature |
# | **density** | Related to alcohol and sugar content; higher density → sweeter wine. | float | Feature |
# | **pH** | Measure of acidity (lower = more acidic). Typical range: 2.9–4.0. | float | Feature |
# | **sulphates** | Contribute to SO₂ levels; act as preservatives and enhance flavor. | float | Feature |
# | **alcohol** | Percentage of alcohol by volume (% ABV). | float | Feature |
# | **quality** | Wine quality score (integer scale, usually 3–8). | int | **Target / Output** |

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %% [markdown]
# - df.hist(...): Automatically creates histograms for each numeric column in the DataFrame.
# - bins=15: Divides the data range into 15 intervals for each histogram.
# - figsize=(15, 10): Sets the overall figure size for better readability.
# - color='crimson': Fills the bars with a deep red color, matching the dataset theme.
# - edgecolor='black': Adds black borders to each bar for visual clarity.
# - plt.suptitle(...): Adds a centered title above all subplots.

# %% [markdown]
# ## Univariate analysis

# %%
df.hist(bins=15,figsize=(15,10),color='crimson',edgecolor='black')
plt.suptitle("distribution of featurs in red wine dataset",fontsize=16)
plt.show()

# %% [markdown]
# ## distribution of target variable

# %%
sns.countplot(x='quality',data=df,hue='quality',palette='Reds')
plt.title("distribution of wine quality")
plt.show()

# %% [markdown]
# ## descriptive statistics summary

# %% [markdown]
# - .T: Transposes the output so that each feature becomes a row and each statistic becomes a column.
# - [['mean', 'std', 'min', 'max']]: Selects only the most relevant statistics for quick inspection

# %%
df.describe().T[['mean','std','min','max']]
# Out:
#                            mean        std      min        max
# fixed acidity          8.319637   1.741096  4.60000   15.90000
# volatile acidity       0.527821   0.179060  0.12000    1.58000
# citric acid            0.270976   0.194801  0.00000    1.00000
# residual sugar         2.538806   1.409928  0.90000   15.50000
# chlorides              0.087467   0.047065  0.01200    0.61100
# free sulfur dioxide   15.874922  10.460157  1.00000   72.00000
# total sulfur dioxide  46.467792  32.895324  6.00000  289.00000
# density                0.996747   0.001887  0.99007    1.00369
# pH                     3.311113   0.154386  2.74000    4.01000
# sulphates              0.658149   0.169507  0.33000    2.00000
# alcohol               10.422983   1.065668  8.40000   14.90000
# quality                5.636023   0.807569  3.00000    8.00000

# %% [markdown]
# ## Boxplots to detect outliers

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df, orient="h", palette="Reds")
plt.title("Boxplot for Outlier Detection in Each Feature")
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# # Relationship between each feature and quality

# %% [markdown]
# ## Continuous vs Categorical

# %%
features = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 
            'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 
            'pH', 'sulphates', 'alcohol']

# %%
plt.figure(figsize=(15,25))

# %% [markdown]
# **enumerate()-It takes a list (or any iterable) and returns pairs of (index, item) as you loop through it.**
# **The reason we use enumerate(features, 1) instead of just enumerate(features) is to start the index from 1 instead of the default 0.**

# %% [markdown]
# - plt.subplot(6,2,i)
#
# - Creates a subplot in a 6×2 grid
# - Arguments: (rows, columns, position)
# - i determines where this plot goes (1st position, 2nd position, etc.)
#
# - sns.boxplot(x='quality',y=col,data=df,palette='Reds')
#
# - Creates a boxplot using seaborn
# - x='quality': quality ratings go on x-axis (like 3, 4, 5, 6, 7, 8)
# - y=col: the current feature goes on y-axis
# - data=df: uses the dataframe 'df'
# - palette='Reds': uses red color scheme

# %%
plt.figure(figsize=(12, 18))
for i,col in enumerate(features,1):
    plt.subplot(6,2,i)
    sns.boxplot(x='quality',y=col,hue='quality',data=df,palette='Reds')
    plt.title(f'{col} vs Quality')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## pairplot used to specify linear and non linear relationship

# %%
sns.pairplot(df[['alcohol', 'volatile acidity', 'sulphates', 'citric acid', 'quality']], 
             hue='quality', palette='Reds')
plt.show()
